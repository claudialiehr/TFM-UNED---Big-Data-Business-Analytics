# %% [markdown]
# # Limpieza y Preparación de datos de adopciones
# Este notebook contiene los pasos para inspeccionar, limpiar y preparar el dataset de adoptantes.

# %% [markdown]
# #### Índice del notebook: Limpieza y Preparación de Datos
#
# ##### 1. Inspección general del dataset
# - 1.1. Información general del dataset
# - 1.2. Características de las columnas
#   - 1.2.1. Tipo de datos
#   - 1.2.2. Valores nulos
#   - 1.2.3. Valores únicos por columna
#   - 1.2.4. Valores duplicados
#   - 1.2.5. Posibles errores ortográficos o inconsistencias de formato
#   - 1.2.6. Estadísticas y observaciones relevantes
#
#
# ##### 2. Correcciones y transformación
# - 2.1. Añadir un ID único
# - 2.2. Limpieza general de texto
# - 2.3. Limpieza específica
#   - 2.3.1. Limpieza de la columna 'fecha'
#   - 2.3.2. Corregir fallos ortograficos en 'poblacion' & 'provincia'
# - 2.4. Clasificación y transformación de variables
#   - 2.4.1. Clasificar columna 'animal'
#   - 2.4.2. Agrupar 'tiempo_disponible' en rangos
#   - 2.4.3. Distribución por tipo de 'vivienda'
#   - 2.4.4. Agrupar rangos de 'edad'
#   - 2.4.5. Distribución por 'horario_laboral'
#   - 2.4.6. Normalizar 'genero'
#   - 2.4.7. Distribución por 'experiencia_animales'
#   - 2.4.8. Normalizar variables de adopción 'devuelto'
# - 2.5. Revisión final
#
#
#
# ##### 3. Guardado del dataset limpio
#
# -------------------------------------------------------------------------------

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

# Ruta al archivo en Drive
ruta = '/content/drive/MyDrive/Dataset_TFM/Datos_Adopciones_Corregido_test.xlsx'

# Cargar el archivo
df = pd.read_excel(ruta)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1.  Inspección general del dataset

# %% [markdown]
# ### 1.1. Información general del dataset

# %%
# Dimensiones del dataset
filas, columnas = df.shape
print(f"📏 El dataset tiene {filas} filas y {columnas} columnas.")
# Out:
# 📏 El dataset tiene 2449 filas y 12 columnas.

# %%
# Vista general del dataset
print("📌 Primeras filas del dataset:")
display(df.head())
# Out:
# 📌 Primeras filas del dataset:
#          animal                fecha       poblacion    provincia nombre  \
# 0          Chia  2002-02-28 00:00:00    28019 Madrid       Madrid  Pedro
# 1      Rasputin  2002-03-04 00:00:00  28922 Alcorcon       Madrid  Sofía
# 2          Zeta  2012-11-24 00:00:00          Madrid       Madrid  Lucía
# 3  Mia ( gata )  2012-12-06 00:00:00          Toledo       Toledo   Luis
# 4          Agua  2012-12-14 00:00:00       Galapagos  Guadalajara  Lucía
#
#    edad genero     vivienda           horario_laboral experiencia_animales  \
# 0    39      M         piso          jornada completa                 baja
# 1    45      F         piso  jornada parcial (mañana)                 baja
# 2    43      F         piso          jornada completa                 baja
# 3    20      M         piso            turno rotativo                media
# 4    49      F  casa/chalet            turno rotativo                 baja
#
#   devuelto tiempo_disponible
# 0     Adop               >5h
# 1     Adop              2-5h
# 2     Adop              2-5h
# 3     Adop              2-5h
# 4     Adop              2-5h

# %% [markdown]
# ### 1.2. Características de las columnas

# %% [markdown]
# #### 1.2.1. Tipo de datos

# %%
df.dtypes.to_frame(name='tipo')
# Out:
#                         tipo
# animal                object
# fecha                 object
# poblacion             object
# provincia             object
# nombre                object
# edad                   int64
# genero                object
# vivienda              object
# horario_laboral       object
# experiencia_animales  object
# devuelto              object
# tiempo_disponible     object

# %%
# Tipos diferentes dentro de cada columna
for col in df.select_dtypes(include='object').columns:
    tipos = df[col].map(type).value_counts()
    if len(tipos) > 1:
        print(f"\n⚠️ Mezcla de tipos en '{col}':")
        print(tipos)
# Out:
# ⚠️ Mezcla de tipos en 'animal':
# animal
# <class 'str'>      2447
# <class 'float'>       2
# Name: count, dtype: int64
#
# ⚠️ Mezcla de tipos en 'fecha':
# fecha
# <class 'datetime.datetime'>    2332
# <class 'str'>                    80
# <class 'int'>                    31
# <class 'float'>                   6
# Name: count, dtype: int64
#
# ⚠️ Mezcla de tipos en 'poblacion':
# poblacion
# <class 'str'>      2446
# <class 'int'>         2
# <class 'float'>       1
# Name: count, dtype: int64
#
# ⚠️ Mezcla de tipos en 'genero':
# genero
# <class 'str'>      2436
# <class 'float'>      13
# Name: count, dtype: int64
#
# ⚠️ Mezcla de tipos en 'experiencia_animales':
# experiencia_animales
# <class 'str'>      2448
# <class 'float'>       1
# Name: count, dtype: int64

# %%
# Convertir columna 'fecha' a datetime
df['fecha'] = pd.to_datetime(df['fecha'], errors='coerce', dayfirst=True)

# %% [markdown]
# #### 1.2.2. Valores nulos

# %%
df.isnull().sum()
# Out:
# animal                   2
# fecha                   68
# poblacion                1
# provincia                0
# nombre                   0
# edad                     0
# genero                  13
# vivienda                 0
# horario_laboral          0
# experiencia_animales     1
# devuelto                 0
# tiempo_disponible        0
# dtype: int64

# %%
import numpy as np

# Reemplazar valores vacíos o solo con espacios por NaN en columnas de texto
for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].apply(lambda x: np.nan if pd.isnull(x) or str(x).strip() == "" else x)

# Mostrar columnas con valores nulos
print("\n Valores nulos después de limpieza de strings vacíos:")
print(df.isnull().sum())
# Out:
#  Valores nulos después de limpieza de strings vacíos:
# animal                   2
# fecha                   68
# poblacion                1
# provincia                0
# nombre                  13
# edad                     0
# genero                  13
# vivienda                 0
# horario_laboral          0
# experiencia_animales     1
# devuelto                16
# tiempo_disponible        0
# dtype: int64

# %% [markdown]
# #### 1.2.3. Valores únicos por columna

# %%
df.nunique()
# Out:
# animal                  1758
# fecha                   1409
# poblacion                733
# provincia                 85
# nombre                   382
# edad                      43
# genero                     7
# vivienda                   5
# horario_laboral            7
# experiencia_animales       3
# devuelto                   7
# tiempo_disponible          3
# dtype: int64

# %% [markdown]
# #### Lo más llamativo:
# - animal	1758	- muchos nombres distintos sin especificar el tipo de animal
# - genero	7	- debería tener 2-3 valores
# - vivienda	4	- conversión a category
# - horario_laboral	5	- lo mismo que vivienda
# - devuelto	8	- demasiados valores, debería ser sí/no

# %% [markdown]
# #### 1.2.4. Valores duplicados

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# No hay filas duplicadas.

# %%
print("Nombres más repetidos:")
print(df['nombre'].value_counts().head(10))

print("\n Animales más repetidos:")
print(df['animal'].value_counts().head(10))
# Out:
# Nombres más repetidos:
# nombre
# Laura     209
# Ana       206
# Sofía     200
# David     200
# Lucía     199
# Juan      196
# Luis      194
# Marta     192
# Pedro     182
# Carlos    178
# Name: count, dtype: int64
#
#  Animales más repetidos:
# animal
# Cachorros              27
# No indica              14
# Cachorro               14
# Zoe                    14
# Linda                  12
# Portos                 12
# Clara                  11
# Rasputin (cachorro)    11
# Olivia                 10
# Copito                 10
# Name: count, dtype: int64

# %% [markdown]
# #### 1.2.5. Posibles errores ortográficos o inconsistencias de formato

# %% [markdown]
# #### Revisión ortográfica reutilizable y corrección manual
#
# Para detectar errores ortográficos o inconsistencias en columnas de texto (como `provincia` o `poblacion`), se creó una función reutilizable basada en `difflib.get_close_matches`. Esta herramienta permite encontrar entradas muy parecidas entre sí, lo cual puede indicar errores de escritura, abreviaciones o variaciones innecesarias.

# %%
import re

def quitar_codigo_postal(valor):
        return re.sub(r'^\d{4,5}\s*', '', str(valor)).strip()

# Aplicar a la columna 'poblacion'
df['poblacion'] = df['poblacion'].apply(quitar_codigo_postal)

# %%
from difflib import get_close_matches

def sugerir_correcciones(df, columna, cutoff=0.8):
    print(f"\n Posibles errores ortográficos en '{columna}':")
    valores = df[columna].dropna().astype(str).str.strip().unique()
    valores = sorted(valores)
    ya_mostrados = set()

    for val in valores:
        if val in ya_mostrados:
            continue
        similares = get_close_matches(val, valores, n=5, cutoff=cutoff)
        if len(similares) > 1:
            print("  -", ", ".join(similares))
            ya_mostrados.update(similares)

# Uso en columnas clave:
sugerir_correcciones(df, 'provincia', cutoff=0.8)
sugerir_correcciones(df, 'poblacion', cutoff=0.9)
# Out:
#  Posibles errores ortográficos en 'provincia':
#   - ASturias, Asturias
#   - Biskaia, Bizkaia
#   - Bizcaia, Bizkaia
#   - Canarias, Cantabria
#   - Castellon, Castellón
#   - Cataluña, Catañuña
#   - Gerona, Girona
#   - MAdrid, Madrid
#   - Madrir, Madrid
#   - No indica, no indica
#   - Pais Vasco, Pais Vazco
#   - Palencia, Valencia
#   - Pontevedra, Pontevedra)
#   - S.C.Tenerife, Tenerife
#   - Toleddo, Toledo
#   - ValenciA, Valencia
#
#  Posibles errores ortográficos en 'poblacion':
#   - ,Madrid, Madrid
#   - Alcala de Henares, Alcalá de Henares
#   - Arcicollar, Arcicóllar
#   - Arganda del Rey, Arganda del rey
#   - Becerril de La Sierra, Becerril de la Sierra
#   - Boadilla del Monte, Boadilla del monte
#   - Cedillo del Condado, Cedillo del condado
#   - Collado Villalba, Collado Villlalba
#   - El Viso San Juan, El Viso de San Juan
#   - La Puebla de Almoradiel, Puebla de Almoradiel
#   - La Torre de Esteban Hambran, La torre de Esteban Hambran
#   - Las Ventas de Retamosa, Ventas de Retamosa
#   - Maddrid, Madrid
#   - Numancia de la Sagra, Numancia de la sagra
#   - Oiartzun, Oirartzun
#   - Paracuellos Jarama, Paracuellos del Jarama
#   - Pozuelo Alarcon, Pozuelo de Alarcon
#   - Rivas - Vaciamadrid, Rivas Vaciamadrid, Rivas Vaciamdadrid, Rivas Vaciamdrid
#   - S. Martin de la Vega, San Martin de la Vega
#   - S.F. Henares, S.F.Henares
#   - S.S. Reyes, S.S.Reyes
#   - S.S.De los Reyes, S.S.de los Reyes
#   - S.Sebastian de los Reyes, San Sebastian de los Reyes
#   - SS de los Reyes, S.S.de los Reyes
#   - San Agustin de Guadalix, San Agustin del Guadalix, San Agustin de Guadallix
#   - San Martín de la Vega, San Martin de la Vega
#   - Señorio Illescas, Señorio de Illescas
#   - Talavera de la REina, Talavera de la Reina
#   - Torrejon de ARdoz, Torrejon de Ardoz
#   - Torrejon de ardoz, Torrejon de Ardoz
#   - Torrejon del Rey, Torrejon del rey
#   - Torrejón de Ardoz., Torrejon de Ardoz
#   - Villabilla, Villalbilla
#   - Villafranca de los Caballeros, Villafranca de los caballeros
#   - Villaluenga de la Sagra, Villaluenga de la sagra
#   - Villanueva d ela Cañada, Villanueva de la Cañada
#   - Villaviciosa de Odon, Villaviciosa de Odón
#   - Yuncos, Yuncoss

# %%
df['genero'].value_counts(dropna=False)
# Out:
# genero
# F         1018
# M          957
# f          243
# m           93
# otro        66
# mujer       42
# hombre      17
# NaN         13
# Name: count, dtype: int64

# %%
df['devuelto'].value_counts(dropna=False)
# Out:
# devuelto
# Adop    928
# No      907
# adop    356
# Sí      205
# x        21
# NaN      16
# Dev      15
# X         1
# Name: count, dtype: int64

# %% [markdown]
# #### 1.2.6. Estadísticas y observaciones relevantes

# %%
# Redondear resultados
print("Edad mínima:", int(df['edad'].min()))
print("Edad máxima:", int(df['edad'].max()))
print("Edad media:", round(df['edad'].mean()))
print("Edad mediana:", int(df['edad'].median()))
print("Desviación estándar:", round(df['edad'].std()))
print("Moda:", int(df['edad'].mode()[0]))
# Out:
# Edad mínima: 18
# Edad máxima: 60
# Edad media: 36
# Edad mediana: 36
# Desviación estándar: 11
# Moda: 41

# %%
cols_interes = ['animal', 'genero', 'vivienda', 'horario_laboral', 'experiencia_animales', 'devuelto']
display(df[cols_interes].describe())
# Out:
#            animal genero vivienda   horario_laboral experiencia_animales  \
# count        2447   2436     2449              2449                 2448
# unique       1758      7        5                 7                    3
# top     Cachorros      F     piso  jornada completa                media
# freq           27   1018     1406              1452                 1046
#
#        devuelto
# count      2433
# unique        7
# top        Adop
# freq        928

# %% [markdown]
# ## 2. Correcciones y transformación

# %% [markdown]
# ### 2.1. Añadir un ID único

# %%
# Añadir ID

df['ID'] = range(1, len(df) + 1)

# Reordenar columnas
cols = ['ID'] + [col for col in df.columns if col != 'ID']
df = df[cols]

# %%
df.head()
# Out:
#    ID        animal      fecha  poblacion    provincia nombre  edad genero  \
# 0   1          Chia 2002-02-28     Madrid       Madrid  Pedro    39      M
# 1   2      Rasputin 2002-03-04   Alcorcon       Madrid  Sofía    45      F
# 2   3          Zeta 2012-11-24     Madrid       Madrid  Lucía    43      F
# 3   4  Mia ( gata ) 2012-12-06     Toledo       Toledo   Luis    20      M
# 4   5          Agua 2012-12-14  Galapagos  Guadalajara  Lucía    49      F
#
#       vivienda           horario_laboral experiencia_animales devuelto  \
# 0         piso          jornada completa                 baja     Adop
# 1         piso  jornada parcial (mañana)                 baja     Adop
# 2         piso          jornada completa                 baja     Adop
# 3         piso            turno rotativo                media     Adop
# 4  casa/chalet            turno rotativo                 baja     Adop
#
#   tiempo_disponible
# 0               >5h
# 1              2-5h
# 2              2-5h
# 3              2-5h
# 4              2-5h

# %% [markdown]
# ### 2.2. Limpieza general de texto

# %% [markdown]
# - Eliminar tildes y caracteres especiales
# - Reemplazar saltos de línea por espacios
# - Normalizar capitalización

# %%
import unicodedata
import re

def limpiar_texto_completo(texto):
    if pd.isnull(texto):
        return texto
    texto = str(texto)
    texto = unicodedata.normalize('NFKD', texto).encode('ASCII', 'ignore').decode('utf-8')
    texto = texto.replace('\n', ' ').replace('\r', ' ')
    texto = re.sub(r'\s+', ' ', texto).strip()
    return texto.title()

columnas_a_normalizar = ['animal', 'provincia', 'poblacion', 'nombre', 'vivienda', 'horario_laboral', 'experiencia_animales', 'devuelto', 'tiempo_disponible']

for col in columnas_a_normalizar:
    df[col] = df[col].apply(limpiar_texto_completo)

# %%
df.head()
# Out:
#    ID        animal      fecha  poblacion    provincia nombre  edad genero  \
# 0   1          Chia 2002-02-28     Madrid       Madrid  Pedro    39      M
# 1   2      Rasputin 2002-03-04   Alcorcon       Madrid  Sofia    45      F
# 2   3          Zeta 2012-11-24     Madrid       Madrid  Lucia    43      F
# 3   4  Mia ( Gata ) 2012-12-06     Toledo       Toledo   Luis    20      M
# 4   5          Agua 2012-12-14  Galapagos  Guadalajara  Lucia    49      F
#
#       vivienda           horario_laboral experiencia_animales devuelto  \
# 0         Piso          Jornada Completa                 Baja     Adop
# 1         Piso  Jornada Parcial (Manana)                 Baja     Adop
# 2         Piso          Jornada Completa                 Baja     Adop
# 3         Piso            Turno Rotativo                Media     Adop
# 4  Casa/Chalet            Turno Rotativo                 Baja     Adop
#
#   tiempo_disponible
# 0               >5H
# 1              2-5H
# 2              2-5H
# 3              2-5H
# 4              2-5H

# %% [markdown]
# ### 2.3. Limpieza específica

# %% [markdown]
# #### 2.3.1. Limpieza de la columna fecha

# %%
# Extraer el año
df['año'] = df['fecha'].dt.year

# Eliminar filas con año nulo
df = df[df['año'].notna()]

# Convertir 'año' a entero
df['año'] = df['año'].astype(int)

# Conteo por año
print("📅 Conteo de registros por año (sin filtrar):")
print(df['año'].value_counts().sort_index())
# Out:
# 📅 Conteo de registros por año (sin filtrar):
# año
# 1905      9
# 1970     31
# 2002      2
# 2004      1
# 2006      2
# 2008      2
# 2009      4
# 2010     25
# 2011     29
# 2012     56
# 2013    218
# 2014    215
# 2015    213
# 2016    205
# 2017    120
# 2018    111
# 2019     94
# 2020     49
# 2021    332
# 2022    281
# 2023    259
# 2024    105
# 2025     17
# 2107      1
# Name: count, dtype: int64

# %% [markdown]
# Se observa que hay registros con años claramente fuera del rango esperable (ej. 1905, 2107), lo cual sugiere errores en la entrada de datos. Por eso se decide conservar solo registros entre 2010 y 2025 para asegurar relevancia y coherencia en el análisis.

# %%
# Crear columna para visualización
df['fecha_europea'] = df['fecha'].dt.strftime('%d/%m/%Y')

# Convertir a date (sin hora)
df['fecha'] = df['fecha'].dt.date

# Eliminar nulos y filtrar rango esperado
df = df[df['año'].notna()]
df = df[df['año'].between(2010, 2025)]

# %%
df[['fecha', 'fecha_europea', 'año']].head()
# Out:
#         fecha fecha_europea   año
# 2  2012-11-24    24/11/2012  2012
# 3  2012-12-06    06/12/2012  2012
# 4  2012-12-14    14/12/2012  2012
# 5  2012-12-20    20/12/2012  2012
# 6  2012-12-22    22/12/2012  2012

# %% [markdown]
# ### 2.3.2. Corregir fallos ortograficos en 'poblacion' & 'provincia'

# %% [markdown]
# #### Corrección de errores ortográficos en 'poblacion' y 'provincia'
#
# Tras normalizar el texto y eliminar códigos postales, aún pueden quedar inconsistencias ortográficas en columnas como 'poblacion' y 'provincia'. Se utiliza una función basada en `difflib` para sugerir valores similares que podrían representar errores de escritura. Esto permite identificar grupos de valores equivalentes y proceder a una corrección manual en los casos más evidentes.

# %%
# Limpiar números al principio de 'provincia' y 'poblacion'
for col in ['provincia', 'poblacion']:
    df[col] = df[col].astype(str).str.replace(r'^\d+\s*', '', regex=True).str.strip()

# %%
df = df[df['poblacion'].notna() & (df['poblacion'].str.strip() != '')]

# %%
import pandas as pd

# Mostrar valores únicos antes de limpieza
print("Provincias únicas ANTES de limpiar:")
print(sorted(df['provincia'].dropna().unique()))
print("\nPoblaciones únicas ANTES de limpiar:")
print(sorted(df['poblacion'].dropna().astype(str).unique()))

# Diccionarios de corrección
correcciones_provincia = {
    'ASturias' : 'Asturias',
    'Madrir': 'Madrid',
    'MAdrid': 'Madrid',
    'Toleddo': 'Toledo',
    'Bizcaya': 'Bizkaia',
    'Biskaia': 'Bizkaia',
    'Bizcaia': 'Bizkaia',
    'Belgica': 'Bélgica',
    'Alemania': 'Alemania',
    'Luxemburgo': 'Luxemburgo',
    'no indica': 'Sin datos',
    'No indica': 'Sin datos',
    '08758 Barcelona': 'Barcelona',
    'Catañuña': 'Cataluña',
    'ValenciA': 'Valencia',
    'Castellón': 'Castellon',
    'Pontevedra)': 'Pontevedra'
}

correcciones_poblacion = {
    ', Cerdanyola Del Valles,' : 'Cerdanyola Del Valles',
    'Collado Villlalba': 'Collado Villalba',
    'S.C.Retamar': 'Santa Cruz Retamar',
    'S.Cugat Del Valles': 'Sant Cugat Del Valles',
    'La Puebla De Almoradiel': 'Puebla De Almoradiel',
    'Rivas Vaciamdadrid': 'Rivas Vaciamadrid',
    'San Rafaelk': 'San Rafael',
    'Maddrid': 'Madrid',
    ',Madrid' : 'Madrid',
    'S.F.Henares': 'San Fernando De Henares',
    'S.F. Henares': 'San Fernando De Henares',
    'S.S. Reyes': 'San Sebastian De Los Reyes',
    'S.S.Reyes': 'San Sebastian De Los Reyes',
    'S.S.De Los Reyes': 'San Sebastian De Los Reyes',
    'S.L.Escorial': 'San Lorenzo De El Escorial',
    'S.L.El Escorial': 'San Lorenzo De El Escorial',
    'S.Esteban De Palautordera': 'Sant Esteve De Palautordera',
    'Anover De Tajo ': 'Anover De Tajo',
}

# Aplicar correcciones
df['provincia'] = df['provincia'].replace(correcciones_provincia)
df['poblacion'] = df['poblacion'].replace(correcciones_poblacion)

# Mostrar valores únicos después de limpieza
print("\nProvincias únicas DESPUÉS de limpiar:")
print(sorted(df['provincia'].dropna().unique()))
print("\nPoblaciones únicas DESPUÉS de limpiar:")
print(sorted(df['poblacion'].dropna().astype(str).unique()))
# Out:
# Provincias únicas ANTES de limpiar:
# ['Alava', 'Albacete', 'Alemania', 'Alicante', 'Almeria', 'Andalucia', 'Asturias', 'Avila', 'Badajoz', 'Badalona', 'Baleares', 'Barcelona', 'Belgica', 'Bilbao', 'Biskaia', 'Bizcaia', 'Bizkaia', 'Burgos', 'Caceres', 'Cadiz', 'Canarias', 'Cantabria', 'Castellon', 'Castilla La Mancha', 'Cataluna', 'Catanuna', 'Ciudad Real', 'Cordoba', 'Cuenca', 'Dinamarca', 'Extremadura', 'Francia', 'Galicia', 'Gerona', 'Girona', 'Granada', 'Guadalajara', 'Guipuzcoa', 'Huelva', 'Huesca', 'Jaen', 'La Coruna', 'La Rioja', 'Leon', 'Luxemburgo', 'Madrid', 'Madrir', 'Malaga', 'Mallorca', 'Murcia', 'Navarra', 'No Indica', 'Olias Del Rey', 'Pais Vasco', 'Pais Vazco', 'Palencia', 'Pamplona', 'Pontevedra', 'Pontevedra)', 'Portugal', 'Reino Unido', 'Rioja', 'S.C.Tenerife', 'Salamanca', 'San Sebastian', 'Segovia', 'Sin Datos', 'Soria', 'Suiza', 'Tarragona', 'Tenerife', 'Toleddo', 'Toledo', 'Valencia', 'Valladolid', 'Valparaiso', 'Vizcaya', 'Zamora', 'Zaragoza']
#
# Poblaciones únicas ANTES de limpiar:
# [', Cerdanyola Del Valles,', ',Madrid', 'Aguilas', 'Agullent', 'Aizarnazabal,', 'Ajofrin', 'Alalpardo', 'Alameda De La Sagra', 'Albacete', 'Albarreal Del Tajo', 'Albiol', 'Alcala De Henares', 'Alcazar De San Juan', 'Alcobendas', 'Alcorcon', 'Alcoy', 'Aldea Del Fresno', 'Aldeamayor De S. Martin', 'Alemania', 'Alfaz Del Pi', 'Algeciras', 'Algemesi', 'Algete', 'Alicante', 'Aljavir', 'Almazan', 'Almazora', 'Almeria', 'Almorox', 'Alovera', 'Alsasua', 'Alzira', 'Amorebieta', 'Amurrio', 'Anover De Tajo', 'Aoiz', 'Aranjuez', 'Aravaca', 'Arcicollar', 'Arevalo', 'Arganda Del Rey', 'Arges', 'Armilla', 'Arroyomolinos', 'Artajona', 'Artea', 'Ascot', 'Ateca', 'Avila', 'Aviles', 'Azucaica', 'Azuqueca', 'Azuqueca De Henares', 'Badajoz', 'Badalona', 'Baracaldo', 'Barcelona', 'Barcience', 'Bargas', 'Batres', 'Becerril De La Sierra', 'Belvis De La Jara', 'Benahadux', 'Benalmadena', 'Benicasim', 'Berga', 'Bilbao', 'Bizkaia', 'Blaco', 'Boadilla Del Monte', 'Boecillo', 'Borgloon', 'Borox', 'Breda', 'Brunete', 'Bufali', 'Burgos', 'Burguillos De Toledo', 'Burlada', 'Burujon', 'Cabanas De La Sagra', 'Cabezo De Torres', 'Caceres', 'Cadalso De Los Vidrios', 'Calella', 'Callosa De Segura', 'Calpe', 'Calsdes De Malavella', 'Camarena', 'Camarma De Esteruelas', 'Candeleda', 'Cantimpalos', 'Carabana', 'Carranque', 'Carriches', 'Cartagena', 'Casarrubios Del Monte', 'Casarrubuelos', 'Casetas', 'Castellon', 'Castellon De La Plana', 'Casteo Urdiales', 'Castiello De Jaca', 'Cazalegas', 'Cebreros', 'Cedillo Del Condado', 'Cercedilla', 'Cervello', 'Chapineria', 'Chiloeches', 'Chinchon', 'Chiva', 'Chozas De Canales', 'Ciempozuelos', 'Ciudad Real', 'Cobeja', 'Cobena', 'Cobisa', 'Collado Mediano', 'Collado Villalba', 'Collado Villlalba', 'Colmenar De Oreja', 'Colmenar Viejo', 'Colmenarejo', 'Colungio', 'Consuegra', 'Corbera De Llobregat', 'Cordoba', 'Corral De Almaguer', 'Corteconcepcion', 'Coslada', 'Cox', 'Cuarte De Huerva', 'Cuenca', 'Daganzo De Arriba', 'Daimus', 'Durango', 'Ea', 'Egues', 'El Alamo', 'El Barraco', 'El Berrueco', 'El Canaveral', 'El Casar', 'El Escorial', 'El Gordo', 'El Masnou', 'El Quinon - Sesena', 'El Rourell', 'El Vendrell', 'El Viso De San Juan', 'El Viso San Juan', 'Elche', 'Errenteria', 'Escalona', 'Escalonilla', 'Espinardo', 'Esquivias', 'Estacion De Cartama', 'Fernan Nunez', 'Ferrol', 'Figueres', 'Flaca', 'Fontanar', 'Fresnedillas De La Oliva', 'Fuencarral', 'Fuenlabrada', 'Fuensalida', 'Fuente El Fresno', 'Galapagar', 'Galapagos', 'Galdakao', 'Galvez', 'Garganta De Los Montes', 'Gernika', 'Gerona', 'Getafe', 'Gijon', 'Girona', 'Grinon', 'Guadalajara', 'Guadamur', 'Guadarrama', 'Hontoba', 'Horcajo De Santiago', 'Hormigos', 'Hoyo De Manzanares', 'Hoyo De Pinares', 'Huarte', 'Huerta De Valdecarabanos', 'Humanes', 'Humanes De Madrid', 'Illescas', 'Iniesta', 'Jaen', 'Javea', 'Kilchberg', 'La Cala De Mijas', 'La Coruna', 'La Navata', 'La Pobla De Vallbona', 'La Puebla De Almoradiel', 'La Puebla De Montalban', 'La Solana', 'La Torre De Esteban Hambran', 'La Turbie', 'La Victoria De Acentejo', 'Laguna De Duero', 'Las Palmas G.Canaria', 'Las Presas', 'Las Rozas', 'Las Ventas De Retamosa', 'Leganes', 'Leioa', 'Leon', 'Leuze En Hainaut', 'Lillo', 'Llanars', 'Llucmayor', 'Loarre', 'Loeches', 'Lominchar', 'Los Yebenes', 'Lugones', 'Luxemburgo', 'Maddrid', 'Madrid', 'Madrid Y Robledo De Chavela', 'Madridejos', 'Magan', 'Majadahonda', 'Malaga', 'Manzanares', 'Manzanares Del Real', 'Marchamalo', 'Martorell', 'Mazarambroz', 'Meco', 'Meggen Lucerna', 'Mejorada Del Campo', 'Menasabas', 'Mendavia', 'Mentrida', 'Merida', 'Miguel Esteban', 'Mirador Los Pinos', 'Miranda De Ebro', 'Mislata', 'Mocejon', 'Moia', 'Moncloa Aravaca', 'Mora', 'Moraleja De Enmedio', 'Moraleja Del Vino', 'Mostoles', 'Mota Del Cuervo', 'Murcia', 'Mutamel', 'Nambroca', 'Nan', 'Navacerrada', 'Navahermosa', 'Navalcarnero', 'Navarra', 'Navarredonda De Gredos', 'Navas De Buitrago', 'Niva', 'No Indica', 'Noblejas', 'Numancia De La Sagra', 'Ocana', 'Oiartzun', 'Oirartzun', 'Olesa De Montserrat ...
#
# Provincias únicas DESPUÉS de limpiar:
# ['Alava', 'Albacete', 'Alemania', 'Alicante', 'Almeria', 'Andalucia', 'Asturias', 'Avila', 'Badajoz', 'Badalona', 'Baleares', 'Barcelona', 'Bilbao', 'Bizkaia', 'Burgos', 'Bélgica', 'Caceres', 'Cadiz', 'Canarias', 'Cantabria', 'Castellon', 'Castilla La Mancha', 'Cataluna', 'Catanuna', 'Ciudad Real', 'Cordoba', 'Cuenca', 'Dinamarca', 'Extremadura', 'Francia', 'Galicia', 'Gerona', 'Girona', 'Granada', 'Guadalajara', 'Guipuzcoa', 'Huelva', 'Huesca', 'Jaen', 'La Coruna', 'La Rioja', 'Leon', 'Luxemburgo', 'Madrid', 'Malaga', 'Mallorca', 'Murcia', 'Navarra', 'No Indica', 'Olias Del Rey', 'Pais Vasco', 'Pais Vazco', 'Palencia', 'Pamplona', 'Pontevedra', 'Portugal', 'Reino Unido', 'Rioja', 'S.C.Tenerife', 'Salamanca', 'San Sebastian', 'Segovia', 'Sin Datos', 'Soria', 'Suiza', 'Tarragona', 'Tenerife', 'Toledo', 'Valencia', 'Valladolid', 'Valparaiso', 'Vizcaya', 'Zamora', 'Zaragoza']
#
# Poblaciones únicas DESPUÉS de limpiar:
# ['Aguilas', 'Agullent', 'Aizarnazabal,', 'Ajofrin', 'Alalpardo', 'Alameda De La Sagra', 'Albacete', 'Albarreal Del Tajo', 'Albiol', 'Alcala De Henares', 'Alcazar De San Juan', 'Alcobendas', 'Alcorcon', 'Alcoy', 'Aldea Del Fresno', 'Aldeamayor De S. Martin', 'Alemania', 'Alfaz Del Pi', 'Algeciras', 'Algemesi', 'Algete', 'Alicante', 'Aljavir', 'Almazan', 'Almazora', 'Almeria', 'Almorox', 'Alovera', 'Alsasua', 'Alzira', 'Amorebieta', 'Amurrio', 'Anover De Tajo', 'Aoiz', 'Aranjuez', 'Aravaca', 'Arcicollar', 'Arevalo', 'Arganda Del Rey', 'Arges', 'Armilla', 'Arroyomolinos', 'Artajona', 'Artea', 'Ascot', 'Ateca', 'Avila', 'Aviles', 'Azucaica', 'Azuqueca', 'Azuqueca De Henares', 'Badajoz', 'Badalona', 'Baracaldo', 'Barcelona', 'Barcience', 'Bargas', 'Batres', 'Becerril De La Sierra', 'Belvis De La Jara', 'Benahadux', 'Benalmadena', 'Benicasim', 'Berga', 'Bilbao', 'Bizkaia', 'Blaco', 'Boadilla Del Monte', 'Boecillo', 'Borgloon', 'Borox', 'Breda', 'Brunete', 'Bufali', 'Burgos', 'Burguillos De Toledo', 'Burlada', 'Burujon', 'Cabanas De La Sagra', 'Cabezo De Torres', 'Caceres', 'Cadalso De Los Vidrios', 'Calella', 'Callosa De Segura', 'Calpe', 'Calsdes De Malavella', 'Camarena', 'Camarma De Esteruelas', 'Candeleda', 'Cantimpalos', 'Carabana', 'Carranque', 'Carriches', 'Cartagena', 'Casarrubios Del Monte', 'Casarrubuelos', 'Casetas', 'Castellon', 'Castellon De La Plana', 'Casteo Urdiales', 'Castiello De Jaca', 'Cazalegas', 'Cebreros', 'Cedillo Del Condado', 'Cercedilla', 'Cerdanyola Del Valles', 'Cervello', 'Chapineria', 'Chiloeches', 'Chinchon', 'Chiva', 'Chozas De Canales', 'Ciempozuelos', 'Ciudad Real', 'Cobeja', 'Cobena', 'Cobisa', 'Collado Mediano', 'Collado Villalba', 'Colmenar De Oreja', 'Colmenar Viejo', 'Colmenarejo', 'Colungio', 'Consuegra', 'Corbera De Llobregat', 'Cordoba', 'Corral De Almaguer', 'Corteconcepcion', 'Coslada', 'Cox', 'Cuarte De Huerva', 'Cuenca', 'Daganzo De Arriba', 'Daimus', 'Durango', 'Ea', 'Egues', 'El Alamo', 'El Barraco', 'El Berrueco', 'El Canaveral', 'El Casar', 'El Escorial', 'El Gordo', 'El Masnou', 'El Quinon - Sesena', 'El Rourell', 'El Vendrell', 'El Viso De San Juan', 'El Viso San Juan', 'Elche', 'Errenteria', 'Escalona', 'Escalonilla', 'Espinardo', 'Esquivias', 'Estacion De Cartama', 'Fernan Nunez', 'Ferrol', 'Figueres', 'Flaca', 'Fontanar', 'Fresnedillas De La Oliva', 'Fuencarral', 'Fuenlabrada', 'Fuensalida', 'Fuente El Fresno', 'Galapagar', 'Galapagos', 'Galdakao', 'Galvez', 'Garganta De Los Montes', 'Gernika', 'Gerona', 'Getafe', 'Gijon', 'Girona', 'Grinon', 'Guadalajara', 'Guadamur', 'Guadarrama', 'Hontoba', 'Horcajo De Santiago', 'Hormigos', 'Hoyo De Manzanares', 'Hoyo De Pinares', 'Huarte', 'Huerta De Valdecarabanos', 'Humanes', 'Humanes De Madrid', 'Illescas', 'Iniesta', 'Jaen', 'Javea', 'Kilchberg', 'La Cala De Mijas', 'La Coruna', 'La Navata', 'La Pobla De Vallbona', 'La Puebla De Montalban', 'La Solana', 'La Torre De Esteban Hambran', 'La Turbie', 'La Victoria De Acentejo', 'Laguna De Duero', 'Las Palmas G.Canaria', 'Las Presas', 'Las Rozas', 'Las Ventas De Retamosa', 'Leganes', 'Leioa', 'Leon', 'Leuze En Hainaut', 'Lillo', 'Llanars', 'Llucmayor', 'Loarre', 'Loeches', 'Lominchar', 'Los Yebenes', 'Lugones', 'Luxemburgo', 'Madrid', 'Madrid Y Robledo De Chavela', 'Madridejos', 'Magan', 'Majadahonda', 'Malaga', 'Manzanares', 'Manzanares Del Real', 'Marchamalo', 'Martorell', 'Mazarambroz', 'Meco', 'Meggen Lucerna', 'Mejorada Del Campo', 'Menasabas', 'Mendavia', 'Mentrida', 'Merida', 'Miguel Esteban', 'Mirador Los Pinos', 'Miranda De Ebro', 'Mislata', 'Mocejon', 'Moia', 'Moncloa Aravaca', 'Mora', 'Moraleja De Enmedio', 'Moraleja Del Vino', 'Mostoles', 'Mota Del Cuervo', 'Murcia', 'Mutamel', 'Nambroca', 'Nan', 'Navacerrada', 'Navahermosa', 'Navalcarnero', 'Navarra', 'Navarredonda De Gredos', 'Navas De Buitrago', 'Niva', 'No Indica', 'Noblejas', 'Numancia De La Sagra', 'Ocana', 'Oiartzun', 'Oirartzun', 'Olesa De Montserrat', 'Olias Del Rey', 'Ontigola', 'Ontinyent', 'Orgaz', 'Otero De Herreros' ...

# %% [markdown]
# ### 2.4. Clasificación y transformación de variables

# %% [markdown]
# #### 2.4.1. Clasificar columna animal

# %%
import re
import pandas as pd

PARENTESIS = re.compile(r"\(([^)]*)\)")

def clasificar_animal(nombre):
    if pd.isna(nombre) or str(nombre).strip() == "":
        return "perro"

    texto = str(nombre)

    # Buscar dentro de paréntesis
    for contenido in PARENTESIS.findall(texto):
        cont = contenido.lower().strip()

        # gato/gata/gatito/gatita
        if re.search(r"\b(gato|gata|gatito|gatita)\b", cont, flags=re.I):
            return "gato"

    return "perro"

# Aplicar al DataFrame
df["tipo_animal"] = df["animal"].apply(clasificar_animal)

# Chequeo rápido
print(df["tipo_animal"].value_counts())
# Out:
# tipo_animal
# perro    2180
# gato      147
# Name: count, dtype: int64

# %%
# Reordenar columnas
cols = df.columns.tolist()
cols.insert(cols.index('animal') + 1, cols.pop(cols.index('tipo_animal')))
df = df[cols]
df.head()
# Out:
#    ID          animal tipo_animal       fecha  poblacion    provincia nombre  \
# 2   3            Zeta       perro  2012-11-24     Madrid       Madrid  Lucia
# 3   4    Mia ( Gata )        gato  2012-12-06     Toledo       Toledo   Luis
# 4   5            Agua       perro  2012-12-14  Galapagos  Guadalajara  Lucia
# 5   6  Beda (Chispa )       perro  2012-12-20     Madrid       Madrid   Luis
# 6   7           Bimbo       perro  2012-12-22       Vigo   Pontevedra  Laura
#
#    edad genero     vivienda          horario_laboral experiencia_animales  \
# 2    43      F         Piso         Jornada Completa                 Baja
# 3    20      M         Piso           Turno Rotativo                Media
# 4    49      F  Casa/Chalet           Turno Rotativo                 Baja
# 5    20      M        Atico         Jornada Completa                 Baja
# 6    19      F  Casa/Chalet  Jornada Parcial (Tarde)                 Alta
#
#   devuelto tiempo_disponible   año fecha_europea
# 2     Adop              2-5H  2012    24/11/2012
# 3     Adop              2-5H  2012    06/12/2012
# 4     Adop              2-5H  2012    14/12/2012
# 5       No              2-5H  2012    20/12/2012
# 6       No              2-5H  2012    22/12/2012

# %% [markdown]
# #### 2.4.2. Agrupar tiempo_disponible en rangos

# %%
mapeo = {
    '<2h': '<1–2h',
    '2-5h': '2–5h',
    '>5h': '>5h'
}

# Aplicar mapeo directamente sobre la columna original
df['tiempo_disponible'] = df['tiempo_disponible'].str.strip().str.lower().map(mapeo)

# %%
print(df['tiempo_disponible'].value_counts())
# Out:
# tiempo_disponible
# 2–5h     1643
# >5h       464
# <1–2h     220
# Name: count, dtype: int64

# %% [markdown]
# #### 2.4.3. Distribución por tipo de vivienda

# %%
# Conteo con frecuencia y porcentaje
vivienda_counts = df['vivienda'].value_counts(dropna=False)
vivienda_percent = df['vivienda'].value_counts(normalize=True, dropna=False) * 100

vivienda_summary = pd.DataFrame({
    'Frecuencia': vivienda_counts,
    'Porcentaje (%)': vivienda_percent.round(2)
})

display(vivienda_summary)
# Out:
#                      Frecuencia  Porcentaje (%)
# vivienda
# Piso                       1344           57.76
# Casa/Chalet                 554           23.81
# Atico                       251           10.79
# Vivienda Compartida         177            7.61
# Piso Compartido               1            0.04

# %%
# Sustituir 'Vivienda Compartida' y 'Piso compartido' en la columna original
df['vivienda'] = df['vivienda'].replace({
    'Vivienda Compartida': 'Vivienda compartida',
    'Piso compartido': 'Vivienda compartida',
    'Piso Compartido': 'Vivienda compartida'
})

# Calcular las frecuencias y porcentajes de la columna ya unificada
vivienda_counts = df['vivienda'].value_counts(dropna=False)
vivienda_percent = df['vivienda'].value_counts(normalize=True, dropna=False) * 100

# Construir el DataFrame resumen
vivienda_summary = pd.DataFrame({
    'Frecuencia': vivienda_counts,
    'Porcentaje (%)': vivienda_percent.round(2)
})

display(vivienda_summary)
# Out:
#                      Frecuencia  Porcentaje (%)
# vivienda
# Piso                       1344           57.76
# Casa/Chalet                 554           23.81
# Atico                       251           10.79
# Vivienda compartida         178            7.65

# %% [markdown]
# ### 2.4.4. Agrupar rangos de edad

# %%
# Columna 'edad' en formato numérico
df.loc[:, "edad"] = pd.to_numeric(df["edad"], errors="coerce")

# Crear rangos de edad
bins = [17, 24, 34, 44, 54, 64, float("inf")]
labels = ["18–24", "25–34", "35–44", "45–54", "55–64", "65+"]

# Asignar cada edad a un grupo
df.loc[:,"grupo_edad"] = pd.cut(df["edad"], bins=bins, labels=labels, right=True, include_lowest=True)

df['grupo_edad'].value_counts().sort_index()
# Out:
# grupo_edad
# 18–24    363
# 25–34    734
# 35–44    705
# 45–54    340
# 55–64    185
# 65+        0
# Name: count, dtype: int64

# %% [markdown]
# #### 2.4.5. Distribución por horario laboral

# %%
# Conteo de categorías en variables clave
columnas = ['horario_laboral']

for col in columnas:
    print(f"\n📊 Distribución de '{col}':")
    print(df[col].value_counts(dropna=False))
# Out:
# 📊 Distribución de 'horario_laboral':
# horario_laboral
# Jornada Completa            1381
# Turno Rotativo               324
# Jornada Parcial (Tarde)      263
# Jornada Parcial (Manana)     225
# Sin Empleo                   128
# Jornada Rotativa               3
# Jornada Parcial                3
# Name: count, dtype: int64

# %% [markdown]
# #### 2.4.6. Normalizar genero

# %%
def normalizar_genero(valor):
    valor = str(valor).strip().lower()

    if valor in ['m', 'masculino', 'hombre']:
        return 'Hombre'
    elif valor in ['f', 'femenino', 'mujer']:
        return 'Mujer'
    else:
        return 'Otro'

df.loc[:, 'genero'] = df['genero'].apply(normalizar_genero)

# %%
df['genero'].value_counts()
# Out:
# genero
# Mujer     1227
# Hombre    1044
# Otro        56
# Name: count, dtype: int64

# %%
df[df['genero'] == 'Otro']
# Out:
#         ID         animal tipo_animal       fecha             poblacion  \
# 2016  2017           Chay       perro  2011-01-12     Alcala De Henares
# 2017  2018           Cuca       perro  2010-01-05           Fuenlabrada
# 2020  2021          Pipin       perro  2012-01-02              Alcorcon
# 2021  2022         Silver       perro  2011-01-09              Mostoles
# 2027  2028         Sombra       perro  2013-09-01                Toledo
# 2028  2029           Romi       perro  2012-09-01                Sesena
# 2032  2033           Moon       perro  2011-01-01              Alcorcon
# 2036  2037           Zazu       perro  2013-07-22                Sesena
# 2041  2042          Vilma       perro  2013-01-08              Illescas
# 2042  2043          Alfil       perro  2014-01-05              Illescas
# 2047  2048           Siro       perro  2015-10-29                Getafe
# 2048  2049         Bonnie       perro  2014-03-11           Fuenlabrada
# 2085  2086            Ina       perro  2012-04-26                Getafe
# 2108  2109   Okupa / Milu       perro  2012-01-08              Mostoles
# 2113  2114    Rana (Duna)       perro  2012-01-03                Getafe
# 2118  2119          Sugar       perro  2011-01-12              Mostoles
# 2196  2197           Jaku       perro  2013-05-01           Fuenlabrada
# 2222  2223           Lisa       perro  2014-10-01                Getafe
# 2291  2292           Javi       perro  2016-05-20                Getafe
# 2302  2303           Vega       perro  2013-02-10                Yuncos
# 2304  2305          Clyde       perro  2013-06-05                Getafe
# 2305  2306            Lex       perro  2014-07-20     Alcala De Henares
# 2308  2309      Picadilly       perro  2013-09-20                Toledo
# 2309  2310   Enzo(Lucero)       perro  2013-07-05               Leganes
# 2310  2311         Morgan       perro  2014-02-20  Talavera De La Reina
# 2311  2312       Sherlock       perro  2015-03-20              Illescas
# 2316  2317         Pangea       perro  2016-10-29                Getafe
# 2331  2332          Orion       perro  2016-09-06           Fuenlabrada
# 2337  2338    Darth Vader       perro  2014-12-17           Fuenlabrada
# 2345  2346       Brooklyn       perro  2015-08-25              Alcorcon
# 2356  2357          Sissi       perro  2015-03-08               Leganes
# 2357  2358         Atenea       perro  2013-10-25           Fuenlabrada
# 2360  2361         Halley       perro  2013-10-16              Mostoles
# 2370  2371         Puzzle       perro  2015-07-17              Mostoles
# 2371  2372         Dakota       perro  2016-06-16               Leganes
# 2373  2374        Charlie       perro  2015-07-07               Leganes
# 2374  2375       Luke Sky       perro  2015-07-14              Mostoles
# 2375  2376          Dulce       perro  2013-03-22              Illescas
# 2380  2381     Clarirrubi       perro  2013-02-10     Alcala De Henares
# 2381  2382       Leonidas       perro  2016-06-14               Leganes
# 2382  2383           Runi       perro  2012-01-01     Alcala De Henares
# 2385  2386           Suso       perro  2012-01-01                Yuncos
# 2393  2394         Darwin       perro  2015-11-15     Alcala De Henares
# 2395  2396       Capucino       perro  2014-11-01     Alcala De Henares
# 2396  2397  Ronaldo/Baron       perro  2011-06-10     Alcala De Henares
# 2397  2398       Conguito       perro  2017-09-17                Getafe
# 2425  2426         Wisper       perro  2013-09-09                Getafe
# 2426  2427         Savana       perro  2010-01-26  Talavera De La Reina
# 2427  2428    Romi (Gato)        gato  2012-10-02              Alcorcon
# 2428  2429          Tanna       perro  2014-11-10                Getafe
# 2429  2430           Valo       perro  2012-09-04                Getafe
# 2430  2431         Simeon       perro  2014-05-05  Talavera De La Reina
# 2433  2434  Flaqui (Gato)        gato  2012-11-02               Leganes
# 2434  2435  Chester Galgo       perro  2016-02-02                Toledo
# 2442  2443          Turco       perro  2010-11-11              Mostoles
# 2443  2444          Athos       perro  2013-08-01              Mostoles
#
#      provincia                     nombre  edad genero             vivienda  \
# 2016    Madrid                        NaN    30   Otro                 Piso
# 2017    Madrid                        NaN    27   Otro                 Piso
# 2020    Madrid                        NaN    38   Otro                 Piso
# 2021    Madrid                        NaN    53   Otro                 Piso
# 2027    Toledo                       Apao    56   Otro  Vivienda compartida
# 2028    Toledo                       Apao    56   Otro                 Piso
# 2032    Madrid                      Torre    37   Otro                 Piso
# 2036    Toledo                        NaN    21   Otro          Casa/Chalet
# 2041    Toledo                       Gaci    24   Otro                 Piso
# 2042    Toledo    Levrier Italia - Gallia    27   Otro  Vivienda compartida
# 2047    Madrid                Italia Gaia    26   Otro          Casa/Chalet
# 2048    Madrid                Italia Gaia    35   Otro                 Piso
# 2085    Madrid        A - Juncal Indurain    45   Otro          Casa/Chalet
# 2108    Madrid                        NaN    37   Otro                 Piso
# 2113    Madrid     A- Adoptamics(Germany)    26   Otro                 Piso
# 2118    Madrid        A - Violant Estrada    36   Otro  Vivienda compartida
# 2196    Madrid                        Ryt    33   Otro          Casa/Chalet
# 2222    Madrid                      Banco    34   Otro          Casa/Chalet
# 2291    Madrid                     Gallia    44   Otro                 Piso
# 2302    Toledo                 Galgoastur    37   Otro                 Piso
# 2304    Madrid           Benjamin Mehnert    39   Otro                 Piso
# 2305    Madrid           Benjamin Mehnert    33   Otro          Casa/Chalet
# 2308    Toledo        Huellas Puertollano    31   Otro          Casa/Chalet
# 2309    Madrid        Huellas Puertollano    40   Otro          Casa/Chalet
# 2310    Toledo        Huellas Puertollano    34   Otro          Casa/Chalet
# 2311    Toledo        Huellas Puertollano    42   Otro          Casa/Chalet
# 2316    Madrid          Santuario Sevilla    58   Otro                 Piso
# 2331    Madrid                     Gallia    34   Otro                Atico
# 2337    Madrid                     Gallia    50   Otro          Casa/Chalet
# 2345    Madrid                     Gallia    20   Otro          Casa/Chalet
# 2356    Madrid                     Gallia    39   Otro                 Piso
# 2357    Madrid                     Gallia    21   Otro                Atico
# 2360    Madrid                        NaN    20   Otro                 Piso
# 2370    Madrid        Huellas Puertollano    24   Otro          Casa/Chalet
# 2371    Madrid        Huellas Puertollano    59   Otro                 Piso
# 2373    Madrid        Huellas Puertollano    37   Otro                 Piso
# 2374    Madrid        Huellas Puertollano    58   Otro          Casa/Chalet
# 2375    Toledo        Huellas Puertollano    27   Otro                 Piso
# 2380    Madrid                Italia Gaia    58   Otro          Casa/Chalet
# 2381    Madrid                Italia Gaia    23   Otro          Casa/Chalet
# 2382    Madrid                        NaN    26   Otro          Casa/Chalet
# 2385    Toledo  Usa Gsp Rercue New Jersey    43   Otro                 Piso
# 2393    Madrid                Puertollano    28   Otro                 Piso
# 2395    Madrid                Puertollano    35   Otro                 Piso
# 2396    Madrid                Puertollano    28   Otro          Casa/Chalet
# 2397    Madrid                Puertollano    26   Otro                 Piso
# 2425    Madrid            Cesion Ayudando    32   Otro  Vivienda compartida
# 2426    Toledo            Cesion Ayudando    33   Otro                 Piso
# 2427    Madrid            Cesion Ayudando    39   Otro                 Piso
# 2428    Madrid            Cesion Ayudando    22   Otro                 Piso
# 2429    Madrid            Cesion Ayudando    44   Otro                 Piso
# 2430    Toledo            Cesion Ayudando    33   Otro                 Piso
# 2433    Madrid            Cesion Ayudando    36   Otro                 Piso
# 2434    Toledo                    Yulaska    19   Otro          Casa/Chalet
# 2442    Madrid              Picochaparral    57   Otro                Atico
# 2443    Madrid             Pico Chaparral    31   Otro                 Piso
#
#                horario_laboral experiencia_animales devuelto  \
# 2016          Jornada Completa                Media        X
# 2017  Jornada Parcial (Manana)                 Alta        X
# 2020          Jornada Completa                Media        X
# 2021          Jornada Completa                 Baja        X
# 2027          Jornada Completa                 Alta        X
# 2028          Jornada Completa                Media        X
# 2032   Jornada Parcial (Tarde)                Media     Adop
# 2036  Jornada Parcial (Manana)                 Baja        X
# 2041          Jornada Completa                Media       Si
# 2042   Jornada Parcial (Tarde)                Media      NaN
# 2047   Jornada Parcial (Tarde)                Media      NaN
# 2048            Turno Rotativo                Media      NaN
# 2085          Jornada Completa                Media     Adop
# 2108            Turno Rotativo                 Baja       Si
# 2113   Jornada Parcial (Tarde)                 Baja     Adop
# 2118   Jornada Parcial (Tarde)                Media     Adop
# 2196            Turno Rotativo                Media     Adop
# 2222            Turno Rotativo                Media     Adop
# 2291          Jornada Completa                Media     Adop
# 2302          Jornada Completa                 Alta     Adop
# 2304            Turno Rotativo                Media     Adop
# 2305   Jornada Parcial (Tarde)                 Baja     Adop
# 2308  Jornada Parcial (Manana)                 Alta       Si
# 2309          Jornada Completa                 Alta     Adop
# 2310          Jornada Completa                Media     Adop
# 2311          Jornada Completa                Media       Si
# 2316   Jornada Parcial (Tarde)                 Baja     Adop
# 2331                Sin Empleo                Media     Adop
# 2337            Turno Rotativo                Media     Adop
# 2345   Jornada Parcial (Tarde)                 Baja     Adop
# 2356          Jornada Completa                 Alta     Adop
# 2357   Jornada Parcial (Tarde)                 Alta     Adop
# 2360          Jornada Completa                 Alta     Adop
# 2370          Jornada Completa                 Alta     Adop
# 2371          Jornada Completa                Media     Adop
# 2373            Turno Rotativo                Media     Adop
# 2374            Turno Rotativo                Media     Adop
# 2375          Jornada Completa                 Baja     Adop
# 2380                Sin Empleo                 Baja     Adop
# 2381          Jornada Completa                 Alta     Adop
# 2382          Jornada Completa                 Alta     Adop
# 2385  Jornada Parcial (Manana)                 Baja     Adop
# 2393            Turno Rotativo                 Baja     Adop
# 2395  Jornada Parcial (Manana)                 Baja     Adop
# 2396          Jornada Completa                 Baja     Adop
# 2397   Jornada Parcial (Tarde)                 Alta     Adop
# 2425   Jornada Parcial (Tarde)                 Baja     Adop
# 2426            Turno Rotativo                Media     Adop
# 2427          Jornada Completa                 Baja     Adop
# 2428          Jornada Completa                 Baja     Adop
# 2429            Turno Rotativo                Media     Adop
# 2430                Sin Empleo                 Alta     Adop
# 2433          Jornada Completa                Media       Si
# 2434          Jornada Completa                 Baja     Adop
# 2442          Jornada Completa                Media      NaN
# 2443   Jornada Parcial (Tarde)                Media       Si
#
#      tiempo_disponible   año fecha_europea grupo_edad
# 2016              2–5h  2011    12/01/2011      25–34
# 2017               >5h  2010    05/01/2010      25–34
# 2020               >5h  2012    02/01/2012      35–44
# 2021             <1–2h  2011    09/01/2011      45–54
# 2027              2–5h  2013    01/09/2013      55–64
# 2028               >5h  2012    01/09/2012      55–64
# 2032               >5h  2011    01/01/2011      35–44
# 2036               >5h  2013    22/07/2013      18–24
# 2041               >5h  2013    08/01/2013      18–24
# 2042               >5h  2014    05/01/2014      25–34
# 2047               >5h  2015    29/10/2015      25–34
# 2048              2–5h  2014    11/03/2014      35–44
# 2085              2–5h  2012    26/04/2012      45–54
# 2108             <1–2h  2012    08/01/2012      35–44
# 2113              2–5h  2012    03/01/2012      25–34
# 2118              2–5h  2011    12/01/2011      35–44
# 2196              2–5h  2013    01/05/2013      25–34
# 2222              2–5h  2014    01/10/2014      25–34
# 2291               >5h  2016    20/05/2016      35–44
# 2302              2–5h  2013    10/02/2013      35–44
# 2304              2–5h  2013    05/06/2013      35–44
# 2305              2–5h  2014    20/07/2014      25–34
# 2308              2–5h  2013    20/09/2013      25–34
# 2309              2–5h  2013    05/07/2013      35–44
# 2310               >5h  2014    20/02/2014      25–34
# 2311              2–5h  2015    20/03/2015      35–44
# 2316              2–5h  2016    29/10/2016      55–64
# 2331              2–5h  2016    06/09/2016      25–34
# 2337              2–5h  2014    17/12/2014      45–54
# 2345              2–5h  2015    25/08/2015      18–24
# 2356              2–5h  2015    08/03/2015      35–44
# 2357              2–5h  2013    25/10/2013      18–24
# 2360              2–5h  2013    16/10/2013      18–24
# 2370              2–5h  2015    17/07/2015      18–24
# 2371             <1–2h  2016    16/06/2016      55–64
# 2373              2–5h  2015    07/07/2015      35–44
# 2374             <1–2h  2015    14/07/2015      55–64
# 2375               >5h  2013    22/03/2013      25–34
# 2380              2–5h  2013    10/02/2013      55–64
# 2381              2–5h  2016    14/06/2016      18–24
# 2382               >5h  2012    01/01/2012      25–34
# 2385              2–5h  2012    01/01/2012      35–44
# 2393              2–5h  2015    15/11/2015      25–34
# 2395               >5h  2014    01/11/2014      35–44
# 2396              2–5h  2011    10/06/2011      25–34
# 2397              2–5h  2017    17/09/2017      25–34
# 2425               >5h  2013    09/09/2013      25–34
# 2426              2–5h  2010    26/01/2010      25–34
# 2427              2–5h  2012    02/10/2012      35–44
# 2428              2–5h  2014    10/11/2014      18–24
# 2429               >5h  2012    04/09/2012      35–44
# 2430              2–5h  2014    05/05/2014      25–34
# 2433              2–5h  2012    02/11/2012      35–44
# 2434              2–5h  2016    02/02/2016      18–24
# 2442              2–5h  2010    11/11/2010      55–64
# 2443               >5h  2013    01/08/2013      25–34

# %% [markdown]
# Nota: La categoría "Otro" suele representar cesiones a otras protectoras o filas sin nombre del adoptante.

# %% [markdown]
# #### 2.4.7. Distribución por experiencia_animales

# %%
df['experiencia_animales'].value_counts()
# Out:
# experiencia_animales
# Media    958
# Alta     855
# Baja     513
# Name: count, dtype: int64

# %% [markdown]
# #### 2.4.8. Normalizar variables de adopción (devuelto)

# %%
def normalizar_devuelto(valor):
    valor = str(valor).strip().lower()
    if valor in ['dev', 'sí', 'si']:
        return 'si'
    elif valor in ['adop', 'no']:
        return 'no'
    else:
        return 'otro'

# Aplicar al dataframe
df.loc[:,'devuelto'] = df['devuelto'].apply(normalizar_devuelto)

# %%
df['devuelto'].value_counts()
# Out:
# devuelto
# no      2091
# si       211
# otro      25
# Name: count, dtype: int64

# %%
df[df['devuelto'] == 'otro']
# Out:
#         ID        animal tipo_animal       fecha          poblacion provincia  \
# 2016  2017          Chay       perro  2011-01-12  Alcala De Henares    Madrid
# 2017  2018          Cuca       perro  2010-01-05        Fuenlabrada    Madrid
# 2019  2020          Nuka       perro  2011-01-10            Leganes    Madrid
# 2020  2021         Pipin       perro  2012-01-02           Alcorcon    Madrid
# 2021  2022        Silver       perro  2011-01-09           Mostoles    Madrid
# 2023  2024        Sultan       perro  2010-01-04             Getafe    Madrid
# 2024  2025       Venus M       perro  2013-04-01           Alcorcon    Madrid
# 2025  2026          Vito       perro  2013-04-01           Mostoles    Madrid
# 2027  2028        Sombra       perro  2013-09-01             Toledo    Toledo
# 2028  2029          Romi       perro  2012-09-01             Sesena    Toledo
# 2036  2037          Zazu       perro  2013-07-22             Sesena    Toledo
# 2037  2038         Zoser       perro  2012-01-01        Fuenlabrada    Madrid
# 2038  2039           Sky       perro  2014-10-10  Alcala De Henares    Madrid
# 2039  2040          Coco       perro  2010-01-01        Fuenlabrada    Madrid
# 2042  2043         Alfil       perro  2014-01-05           Illescas    Toledo
# 2047  2048          Siro       perro  2015-10-29             Getafe    Madrid
# 2048  2049        Bonnie       perro  2014-03-11        Fuenlabrada    Madrid
# 2439  2440  Michi (Gato)        gato  2015-04-24           Alcorcon    Madrid
# 2440  2441  Rison (Gato)        gato  2014-03-29             Sesena    Toledo
# 2441  2442           Sam       perro  2012-02-01             Yuncos    Toledo
# 2442  2443         Turco       perro  2010-11-11           Mostoles    Madrid
# 2445  2446        Maruxa       perro  2017-05-20           Mostoles    Madrid
# 2446  2447         Paula       perro  2012-08-01            Leganes    Madrid
# 2447  2448        Aritza       perro  2016-10-30           Alcorcon    Madrid
# 2448  2449           Yen       perro  2017-04-01             Sesena    Toledo
#
#                        nombre  edad  genero             vivienda  \
# 2016                      NaN    30    Otro                 Piso
# 2017                      NaN    27    Otro                 Piso
# 2019      A - Teresa San Jose    19   Mujer                 Piso
# 2020                      NaN    38    Otro                 Piso
# 2021                      NaN    53    Otro                 Piso
# 2023            Tamara Y Ruth    51   Mujer          Casa/Chalet
# 2024                 A- Pilar    20   Mujer                 Piso
# 2025                    Graci    58   Mujer          Casa/Chalet
# 2027                     Apao    56    Otro  Vivienda compartida
# 2028                     Apao    56    Otro                 Piso
# 2036                      NaN    21    Otro          Casa/Chalet
# 2037   A- Juan Carlos Mengual    27  Hombre                Atico
# 2038                   Vanesa    24   Mujer                 Piso
# 2039                    Maria    42   Mujer          Casa/Chalet
# 2042  Levrier Italia - Gallia    27    Otro  Vivienda compartida
# 2047              Italia Gaia    26    Otro          Casa/Chalet
# 2048              Italia Gaia    35    Otro                 Piso
# 2439            Raquel Moreno    26   Mujer          Casa/Chalet
# 2440                     Susy    38   Mujer          Casa/Chalet
# 2441                    Rocio    39   Mujer                 Piso
# 2442            Picochaparral    57    Otro                Atico
# 2445            Silvia Careas    29   Mujer          Casa/Chalet
# 2446                   Carmen    38   Mujer                 Piso
# 2447                      Tam    55   Mujer                Atico
# 2448                      Tam    30   Mujer          Casa/Chalet
#
#                horario_laboral experiencia_animales devuelto  \
# 2016          Jornada Completa                Media     otro
# 2017  Jornada Parcial (Manana)                 Alta     otro
# 2019  Jornada Parcial (Manana)                Media     otro
# 2020          Jornada Completa                Media     otro
# 2021          Jornada Completa                 Baja     otro
# 2023            Turno Rotativo                Media     otro
# 2024                Sin Empleo                Media     otro
# 2025          Jornada Completa                 Alta     otro
# 2027          Jornada Completa                 Alta     otro
# 2028          Jornada Completa                Media     otro
# 2036  Jornada Parcial (Manana)                 Baja     otro
# 2037          Jornada Completa                Media     otro
# 2038          Jornada Completa                 Alta     otro
# 2039          Jornada Completa                Media     otro
# 2042   Jornada Parcial (Tarde)                Media     otro
# 2047   Jornada Parcial (Tarde)                Media     otro
# 2048            Turno Rotativo                Media     otro
# 2439   Jornada Parcial (Tarde)                Media     otro
# 2440  Jornada Parcial (Manana)                 Alta     otro
# 2441          Jornada Completa                Media     otro
# 2442          Jornada Completa                Media     otro
# 2445          Jornada Completa                Media     otro
# 2446   Jornada Parcial (Tarde)                Media     otro
# 2447          Jornada Completa                 Alta     otro
# 2448          Jornada Completa                 Alta     otro
#
#      tiempo_disponible   año fecha_europea grupo_edad
# 2016              2–5h  2011    12/01/2011      25–34
# 2017               >5h  2010    05/01/2010      25–34
# 2019              2–5h  2011    10/01/2011      18–24
# 2020               >5h  2012    02/01/2012      35–44
# 2021             <1–2h  2011    09/01/2011      45–54
# 2023              2–5h  2010    04/01/2010      45–54
# 2024              2–5h  2013    01/04/2013      18–24
# 2025              2–5h  2013    01/04/2013      55–64
# 2027              2–5h  2013    01/09/2013      55–64
# 2028               >5h  2012    01/09/2012      55–64
# 2036               >5h  2013    22/07/2013      18–24
# 2037              2–5h  2012    01/01/2012      25–34
# 2038               >5h  2014    10/10/2014      18–24
# 2039               >5h  2010    01/01/2010      35–44
# 2042               >5h  2014    05/01/2014      25–34
# 2047               >5h  2015    29/10/2015      25–34
# 2048              2–5h  2014    11/03/2014      35–44
# 2439              2–5h  2015    24/04/2015      25–34
# 2440              2–5h  2014    29/03/2014      35–44
# 2441              2–5h  2012    01/02/2012      35–44
# 2442              2–5h  2010    11/11/2010      55–64
# 2445              2–5h  2017    20/05/2017      25–34
# 2446             <1–2h  2012    01/08/2012      35–44
# 2447              2–5h  2016    30/10/2016      55–64
# 2448              2–5h  2017    01/04/2017      25–34

# %% [markdown]
# Se normalizó la columna `devuelto` agrupando respuestas como "sí", "dev" y "si" bajo `sí`, y "no", "adop" bajo `no`. Las respuestas no clasificables se etiquetan como `otro`, y pueden excluirse.

# %% [markdown]
# ### 2.5. Revisión final

# %%
# Verificar si quedan valores nulos
print(df.isnull().sum())
# Out:
# ID                      0
# animal                  0
# tipo_animal             0
# fecha                   0
# poblacion               0
# provincia               0
# nombre                  8
# edad                    0
# genero                  0
# vivienda                0
# horario_laboral         0
# experiencia_animales    1
# devuelto                0
# tiempo_disponible       0
# año                     0
# fecha_europea           0
# grupo_edad              0
# dtype: int64

# %%
# Normalizar la columna a texto para buscar '0' y valores vacíos en 'nombre'
col_exp = df['nombre'].astype(str).str.strip()

# Filtrar filas (NaN/""/None)
filas_exp_cero = df[(col_exp == '0') | (df['nombre'].isna())]

print("Filas con valor 0 o nulo en nombre:", len(filas_exp_cero))
print(filas_exp_cero[['animal','tipo_animal', 'nombre', 'experiencia_animales', 'genero', 'devuelto']])
# Out:
# Filas con valor 0 o nulo en nombre: 8
#             animal tipo_animal nombre experiencia_animales genero devuelto
# 2016          Chay       perro    NaN                Media   Otro     otro
# 2017          Cuca       perro    NaN                 Alta   Otro     otro
# 2020         Pipin       perro    NaN                Media   Otro     otro
# 2021        Silver       perro    NaN                 Baja   Otro     otro
# 2036          Zazu       perro    NaN                 Baja   Otro     otro
# 2108  Okupa / Milu       perro    NaN                 Baja   Otro       si
# 2360        Halley       perro    NaN                 Alta   Otro       no
# 2382          Runi       perro    NaN                 Alta   Otro       no

# %%
# Eliminar filas con valores nulos en la columna 'nombre'
df = df.dropna(subset=['nombre']).reset_index(drop=True)

# %%
# Normalizar la columna a texto para buscar '0' y valores vacíos en 'experiencia_animales'
col_exp = df['experiencia_animales'].astype(str).str.strip()

# Filtrar filas (NaN/""/None)
filas_exp_cero = df[(col_exp == '0') | (df['experiencia_animales'].isna())]

print("Filas con valor 0 o nulo en experiencia_animales:", len(filas_exp_cero))
print(filas_exp_cero[['animal', 'experiencia_animales', 'genero', 'devuelto']])
# Out:
# Filas con valor 0 o nulo en experiencia_animales: 1
#               animal experiencia_animales genero devuelto
# 1999  Marieta (Gata)                  NaN  Mujer       no

# %%
# Sustituir los valores NaN en experiencia_animales por 'baja'
df['experiencia_animales'] = df['experiencia_animales'].fillna('baja')

# %% [markdown]
# Las filas en las que el campo 'nombre' aparece vacío se han eliminado del análisis, ya que sin el nombre del adoptante no es posible inferir con fiabilidad el género, variable que considero clave en este estudio. Además, estos registros representan únicamente 8 casos, por lo que su exclusión no afecta de manera significativa a los resultados finales.

# %%
# Verificar si quedan valores nulos
print(df.isnull().sum())
# Out:
# ID                      0
# animal                  0
# tipo_animal             0
# fecha                   0
# poblacion               0
# provincia               0
# nombre                  0
# edad                    0
# genero                  0
# vivienda                0
# horario_laboral         0
# experiencia_animales    0
# devuelto                0
# tiempo_disponible       0
# año                     0
# fecha_europea           0
# grupo_edad              0
# dtype: int64

# %% [markdown]
# ## 3. Guardar dataset limpio

# %%
# Guardar dataset limpio
ruta_guardado = "/content/drive/MyDrive/Dataset_TFM/datos_adopciones_limpio_test.xlsx"

# Exportar a Excel
df.to_excel(ruta_guardado, index=False)

print(f"Dataset guardado correctamente en: {ruta_guardado}")
# Out:
# Dataset guardado correctamente en: /content/drive/MyDrive/Dataset_TFM/datos_adopciones_limpio_test.xlsx
